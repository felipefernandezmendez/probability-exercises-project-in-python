# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
import numpy as np

def tirar_dados(n_tiradas):


 exito = 0
 
 for i in range(n_tiradas):
    dado_1 = np.random.randint(1,7)
    dado_2 = np.random.randint(1,7)
    resultado = dado_1 + dado_2
    
    if (resultado > 7) or (resultado % 2 == 0):
       exito += 1
       
 print(f"Los casos en los que se cumplen las condiciones son {exito}")
 print(f"Las probabilidades de éxito son {exito/n_tiradas*100} %")
 
   

tirar_dados(100000)
# Out:
# Los casos en los que se cumplen las condiciones son 66804
# Las probabilidades de éxito son 66.804 %

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"


            
# TODO


def experiment(n):
 same_color = 0
 tres_blancas_tres_rojas = 0
 bolas = ["White", "Red", "Green"]
 prob_blanca = 10/60
 prob_roja = 20/60
 prob_verde = 30/60

 for x in range(n):
    saca_bola = np.random.choice(bolas, size=5, p=[prob_blanca, prob_roja, prob_verde])
    rojas = np.count_nonzero(saca_bola == "Red")
    blancas = np.count_nonzero(saca_bola == "White")
    verdes = np.count_nonzero(saca_bola == "Green")

    if blancas == 3 and rojas == 2:
       tres_blancas_tres_rojas += 1

    if blancas == 5 or rojas == 5 or verdes == 5:
       same_color += 1
    

 print(f"Las posibilidaddes en", n, f"tiros, de que salgan tres bolas blancas y dos bolas tojas son del {tres_blancas_tres_rojas/n*100} %")
 print(f"Las posibilidades de uqe salga algún lote con todas las boals del mismo color son del {same_color/n*100} %")





    

    



experiment(1000)
# Out:
# Las posibilidaddes en 1000 tiros, de que salgan tres bolas blancas y dos bolas tojas son del 0.0 %
# Las posibilidades de uqe salga algún lote con todas las boals del mismo color son del 0.4 %
